# %% [markdown]
# # TinyNav Colab Training (20-frame camera stack)
#
# Paper: https://arxiv.org/abs/2603.11071
#
# 1. Runtime → Change runtime type → **GPU**
# 2. Upload `dataset.zip` and `train_colab.py`
# 3. Run all cells
# 4. Download `models/best_model.keras`, then locally run `python notebooks/quantize_model.py`

# %%
# !pip -q install opencv-python-headless scikit-learn
from google.colab import files
uploaded = files.upload()

# %%
# %run train_colab.py
